# %%
import numpy as np

# %%
input()

def underline(position): # for stress, the stressed position is underlined
    position_temp = ''
    for i in position:
        position_temp += i + '\033[4m'
    return position_temp

# user chooses meaning and the base-form transitivity and infinitive associated with it , from the verb list

# once they choose meaning and base-form transitivity, the oher positions are specified based on the verb list. for example:
meaning = 'cry'
pm3a = ''
pm3b = 'be'
pm2 = ''
pm1 = ''
p0a = 'rban'
p0b = ''
pp1 = ''
pp2 = ''
pp3 = ''
pp4 = ''
lexical_transitivity = 'intrans' # transitivity of the base form, which is difernet from calculated transitivity of the verb

tense_options = ['present','past']
tense = #user chooses tense

if tense == 'present':
    if  pp2 == '': #imperative modality is incompatiable with 'i' in pp2
        modality_options = ['imperative', 'subjunctive', 'indicative']
    elif pp2 == 'i':
        modality_options = ['subjunctive', 'indicative']
    else: 
        raise Exception('present-modality options error')

    modality = 
    if modality == 'imperative':
        person_options = ['ss','sp'] #imperative verbs are only made for second person
    elif  modality == 'subjunctive' or modality == 'indicative':
        person_options = ['fs', 'ss', 'tsm', 'tsf', 'fp', 'sp', 'tp']
        person = 
    else: 
        raise Exception('present- person selections error')

    if modality == 'imperative':
        if  person == 'ss':
            pp4 = '∅' #bc this produces underlying morphological forms, null morphemes are written
        elif person == 'sp': # for rsecond dperson plural
            pp4 = 'ʌ'
        else:
            raise Exception('present - imperative-pp4 error')

    elif modality == 'indicative' or modality == 'subjunctive':
        if person == 'fs':
            pp4 = 'em(ɛ)'
        elif person == 'ss':
            pp4 = 'i'
        elif person == 'tsm':
            pp4 = 'e'
        elif person == 'tsf':
            pp4 = 'iɛ'
        elif person == '1p':
            pp4 = 'om'
        elif person == '2p':
            pp4 = 'ʌ'
        elif person == 'tp':
            pp4 = 'endɛ'

    if modality == 'indicative':
        aspect_options = ['imperfective', 'neutral'] 
        aspect = 
        if aspect == 'imperfective':
            pm2 = 'me'
            pm3b = ''

    polarity_options = ['negative', 'affirmative']
    polarity = 

    if polarity == 'negative':
        if modality == 'imperative':
            pm1 = 'ma'
        elif modality == 'indicative' or modality == 'subjunctive':
            pm1 = 'ne'
        pm1 = underline(pm1)
        pm3b = '' #so the content of pm3b is ovverriden due to negation      
    elif polarity == 'affirmative':
        if modality == 'imperative' or modality == 'subjunctive':
            if pm3a != '': #if a verb has a preverb, pv gets stressed
                pm3a = underline(pm3a)
            elif pm3a == ''
                p0a = underline(p0a) #stem gets stressed instead
        elif modality == 'indicative':
            pp4 = underline(pp4) # in indicative verbs, AGR is stressed
                
elif tense == 'past':
    person_options = ['fs', 'ss', 'tsm', 'tsf', 'fp', 'sp', 'tp'] #past tense verbs are inflected for all persons
    person = 
    
    if pp1 == 'den' or pp2 == 'i': # if one of these positions is filled
        pp3 = 'ast' # then there needs to be 'ast' in pp3
    elif pp1 == '' and pp2 == '' and p0b == '': #if both of pp1 and pp2 are empty and verb lacks a past stem
        pp3 = 'ast' #the past tense has to be marked with 'ast'
    else: # for instance whenp0b is not empty (verb has a past stem)
        p0a = ''
        p0b = #what the table has listed  # means past tense needs to be marked using past stem

# since the choice of agreement in pp4 is dependent on the calculated transntivity of verb, let's first set of the calculated transitivity of verb
    if pp2 == 'i' and pp1 == 'den': # verbs with both  'i' and 'den' are all intransitive
        calculated_transitivity = 'intrans'
    elif pp2 == 'i': # verbs with 'i' in ppm are all intransitive
        calculated_transitivity = 'intrans'
    elif pp1 == 'den': # verbs without 'i' that have 'den' in pp1 are all transitive
        calculated_transitivity = 'trans'
    elif lexical_transitivity == 'intrans': # verbs without 'i' and 'den' whose base form is intransitive, are calculated as intransitive
        calculated_transitivity = 'intrans'
    elif lexical_transitivity == 'trans': # verbs without 'i' and 'den' whose base form is transitive, are caluclated as transitive
        calculated_transitivity = 'trans'

    modality_options = ['subjunctive', 'indicative']
    modality = 
    if calculated_transitivity == 'intrans' and modality == 'subjunctive':
        if person == 'fs':
            pp4 = 'abim(ɛ)'
        elif person == 'ss':
            pp4 = 'abiʃ(ɛ)'
        elif person == 'tsm':
            pp4 = 'abe'
        elif person == 'tsf':
            pp4 = 'abiɛ'
        elif person == '1p':
            pp4 = 'abimon'
        elif person == '2p':
            pp4 = 'abion'
        elif person == 'tp':
            pp4 = 'abindɛ'

    elif calculated_transitivity == 'trans' and modality == 'subjunctive':
        if person == 'fs':
            pp4 = 'abim(ɛ)'
        elif person == 'ss':
            pp4 = 'abi'
        elif person == 'tsm':
            pp4 = 'abiʃ(ɛ)'
        elif person == 'tsf':
            pp4 = 'abiʃ(ɛ)'
        elif person == '1p':
            pp4 = 'abimon'
        elif person == '2p':
            pp4 = 'abion'
        elif person == 'tp':
            pp4 = 'abindɛ'
   
    elif calculated_transitivity == 'intrans' and modality == 'indicative':
        if person == 'fs':
            pp4 = 'im(ɛ)'
        elif person == 'ss':
            pp4 = 'iʃ(ɛ)'
        elif person == 'tsm':
            pp4 = '∅'
        elif person == 'tsf':
            pp4 = 'ɛ'
        elif person == '1p':
            pp4 = 'imon'
        elif person == '2p':
            pp4 = 'ion'
        elif person == 'tp':
            pp4 = 'indɛ'
    elif calculated_transitivity == 'trans' and modality == 'indicative':
        if person == 'fs':
            pp4 = 'em(ɛ)'
        elif person == 'ss':
            pp4 = 'i'
        elif person == 'tsm':
            pp4 = 'eʃ(ɛ)'
        elif person == 'tsf':
            pp4 = 'eʃ(ɛ)'
        elif person == '1p':
            pp4 = 'emon'
        elif person == '2p':
            pp4 = 'ion'
        elif person == 'tp':
            pp4 = 'eʃon'
    
    aspect_options = ['perfect', 'pluperfect', 'neutral', 'imperfective']
    aspect = 

    if calculated_transitivity == 'intrans' and aspect == 'perfect':
        if person == 'fs':
            pp4 = 'aim(ɛ)'
        elif person == 'ss':
            pp4 = 'aiʃ(ɛ)'
        elif person == 'tsm':
            pp4 = 'i'
        elif person == 'tsf':
            pp4 = 'iʌ'
        elif person == '1p':
            pp4 = 'aimon'
        elif person == '2p':
            pp4 = 'aion'
        elif person == 'tp':
            pp4 = 'indɛ'

    elif calculated_transitivity == 'trans' and aspect == 'perfect':
        if person == 'fs':
            pp4 = 'im(ɛ)'
        elif person == 'ss':
            pp4 = 'i'
        elif person == 'tsm':
             pp4 = 'iʃ(ɛ)'
        elif person == 'tsf':
            pp4 = 'iʃ(ɛ)'
        elif person == '1p':
            pp4 = 'imon'
        elif person == '2p':
            pp4 = 'ion'
        elif person == 'tp':
            pp4 = 'iʃon'
   
    elif calculated_transitivity == 'intrans' and aspect == 'pluperfect':
        if person == 'fs':
             pp4 = 'avim(ɛ)'
        elif person == 'ss':
            pp4 = 'aviʃ(ɛ)'
        elif person == 'tsm':
            pp4 = 'ave'
        elif person == 'tsf':
            pp4 = 'aviɛ'
        elif person == '1p':
            pp4 = 'avimon'
        elif person == '2p':
            pp4 = 'avion'
        elif person == 'tp':
            pp4 = 'avindɛ'
    elif calculated_transitivity == 'trans' and aspect == 'pluperfect':
        if person == 'fs':
            pp4 = 'avim(ɛ)'
        elif person == 'ss':
            pp4 = 'avi'
        elif person == 'tsm':
            pp4 = 'aviʃ(ɛ)'
        elif person == 'tsf':
            pp4 = 'aviʃ(ɛ)'
        elif person == '1p':
            pp4 = 'avimon'
        elif person == '2p':
            pp4 = 'avion'
        elif person == 'tp':
            pp4 = 'avindɛ'
            
     elif calculated_transitivity == 'intrans' and aspect == 'imperfective' or aspect == 'neutral':
        if person == 'fs':
            pp4 = 'im(ɛ)'
        elif person == 'ss':
            pp4 = 'iʃ(ɛ)'
        elif person == 'tsm':
            pp4 = '∅'
        elif person == 'tsf':
            pp4 = 'ɛ'
        elif person == '1p':
            pp4 = 'imon'
        elif person == '2p':
            pp4 = 'ion'
        elif person == 'tp':
            pp4 = 'indɛ'

    elif calculated_transitivity == 'trans' and aspect == 'imperfective' or aspect == 'neutral':
     
        if person == 'fs':
            pp4 = 'em(ɛ)'
        elif person == 'ss':
            pp4 = 'i'
        elif person == 'tsm':
            pp4 = 'eʃ(ɛ)'
        elif person == 'tsf':
            pp4 = 'eʃ(ɛ)'
        elif person == '1p':
            pp4 = 'emon'
        elif person == '2p':
            pp4 = 'ion'
        elif person == 'tp':
            pp4 = 'eʃon'       


    if aspect == 'imperfective':
        pm2 = 'me'
        # imperfective verbs cannot have their pm3b filled
        pm3b = '' 

    polarity_options = ['negative', 'affrimative']
    polarity = 
    if polarity == 'negative':
        pm1 = 'ne'
        pm1 = underline(pm1)
        #negative verbs cannot have their pm3b filled
        pm3b = ''
        
    else: #polarity is affirmative
        if aspect == 'perfect' or aspect == 'pluperfect' or modality == 'subjunctive':
            pp4 = underline(pp4)
        else: # nuetral aspect is marked by stress, in past tense verbs
            if pp3 == 'ast':
                pp3 = underline(pp3)
            elif pp3 == '':
                p0b = underline(p0b)
